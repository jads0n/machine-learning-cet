# %%
import numpy as np

w = [0.4, -0.6, 0.6]
limiar = 0.5
taxa = 0.4
d = -1

x1 = [0, 0, 1]
x2 = [1, 1, 0] 

def percep(vetor):
  m = np.multiply(vetor,w)
  
  u = np.sum(m) -limiar
  
  if (u>0):
    return y = 1
  else:
    return y = -1

  
w[i] = w[i] + taxa*vetor*(d - y)
# Out:
# -1
